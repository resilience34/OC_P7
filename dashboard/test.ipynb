# %%
import pandas as pd
import numpy as np
from flask import Flask, render_template, url_for, request,jsonify
import pickle
import math
import base64
from zipfile import ZipFile
from lightgbm import LGBMClassifier
import uvicorn
import requests 
import json

# %%
#to run :
#en mode local :dans le dossier du fichier api.py faire python app.py puis dans le navigateur aller à http://127.0.0.1:5000/

# imporeter les packages et librairies 
import pandas as pd
import numpy as np
from flask import Flask, render_template, url_for, request,jsonify
import pickle
import math
import base64
from zipfile import ZipFile
from lightgbm import LGBMClassifier
import uvicorn
import api

# Charger le fichier de données à partir de l'archive zip et le lire en tant que dataframe
z = ZipFile("df_test_imputed.zip") # le dataset final avec Standardisation et encodage
dataframe = pd.read_csv(z.open('df_test_imputed.csv'), index_col='SK_ID_CURR', encoding ='utf-8')

# extrait tous les ID client uniques du dataframe et les stocke dans la liste
#all_id_client = list(dataframe['SK_ID_CURR'].unique())

# Charger le modèle entraîné à partir dcustomer_not_foundu fichier pickle
model = pickle.load(open('best_final_prediction.pickle', 'rb'))

# %%
url = "http://127.0.0.1:5000/check_id/{id_client}"

#url = "http://127.0.0.1:5000/client_id"

# %%
id_client = 100001

# %%
  # Préparer l'URL de l'API en remplaçant {id_client} par l'ID du client réel
api_url = url.replace("{id_client}", str(id_client))
api_url
# Out:
# 'http://127.0.0.1:5000/check_id/100245'

# %%
# Envoyer la requête GET à l'API de prédiction
response = requests.get(api_url)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.text

# %%
data = response.json()

# %%
import pandas as pd

# Supposons que vous ayez reçu les données dans une variable 'json_data'
df = pd.read_json(data)
df
# Out:
#    SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      100245         Cash_loans           F            N               N
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0            112500      364896      20947.5           315000
#
#   NAME_TYPE_SUITE NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0   Unaccompanied          Working   Incomplete_higher            Married
#
#    NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0  House_/_apartment                    0.016612      -13365          -1397
#
#    DAYS_REGISTRATION  DAYS_ID_PUBLISH  FLAG_MOBIL  FLAG_EMP_PHONE  \
# 0              -5725            -5788           1               1
#
#    FLAG_WORK_PHONE  FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  \
# 0                0                 1           0           0                2
#
#    REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# ...

# %%
# Créer un DataFrame à partir de l'objet JSON
df = pd.DataFrame(data)
df
# Out:
#    SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      100245         Cash_loans           F            N               N
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0          112500.0    364896.0      20947.5         315000.0
#
#   NAME_TYPE_SUITE NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0   Unaccompanied          Working   Incomplete_higher            Married
#
#    NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0  House_/_apartment                    0.016612      -13365        -1397.0
#
#    DAYS_REGISTRATION  DAYS_ID_PUBLISH  FLAG_MOBIL  FLAG_EMP_PHONE  \
# 0            -5725.0            -5788           1               1
#
#    FLAG_WORK_PHONE  FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  \
# 0                0                 1           0           0              2.0
#
#    REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# ...

# %%
df.shape
# Out:
# (1, 112)

# %%
df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_63244\291628753.py in ?()
# ----> 1 df = pd.DataFrame(data)
#       2 df
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     813                 )
#     814         # For data is scalar
#     815         else:
#     816             if index is None or columns is None:
# --> 817                 raise ValueError("DataFrame constructor not properly called!")
#     818
#     819             index = ensure_index(index)
#     820             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
df = pd.DataFrame(data)
df.shape
# Out:
# (1, 112)

# %%
z = ZipFile("data/real_data_clean_test.zip")
data_origin = pd.read_csv(z.open('real_data_clean_test.csv'), encoding ='utf-8')

# %%
data_origin=data_origin[data_origin["SK_ID_CURR"]==id_client]
data_origin
# Out:
#     SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 14      100245         Cash_loans           F            N               N
#
#     CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 14             0          112500.0    364896.0      20947.5         315000.0
#
#     ... AGE DAYS_EMPLOYED_ANOM PREVIOUS_APPLICATION_COUNT MOST_CREDIT_TYPE  \
# 14  ...  37              False                       10.0  Consumer_credit
#
#    PREVIOUS_LOANS_COUNT  CREDIT_PERCENT_INCOME  ANNUITY_CREDIT_PERCENT_INCOME  \
# 14                  NaN                3.24352                         0.1862
#
#     CREDIT_REFUND_TIME  DAYS_EMPLOYED_PERCENT  EXT_SOURCE_1
# 14           17.419549               0.104527      0.637953
#
# [1 rows x 112 columns]

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 250)

# %%
# Comparer les lignes
resultat = df.iloc[0].equals(data_origin.iloc[0])

# Afficher le résultat
resultat
# Out:
# False

# %%
df["NAME_TYPE_SUITE"]
# Out:
# 14    Unaccompanied
# Name: NAME_TYPE_SUITE, dtype: object

# %%
def predict_loan_approval(id_client, url): # fonction via API
    # Préparer les données pour la requête
    #data = {'id_client': id_client}
    id_client = int(id_client)

    # lien vers la fonction + id 
    id = "/{id_client}"
    url2 = url+id

    # Préparer l'URL de l'API en remplaçant {id_client} par l'ID du client réel
    api_url = url2.replace("{id_client}", str(id_client))

    # Envoyer la requête GET à l'API de prédiction
    response = requests.get(api_url)

    # Vérifier si la requête a réussi (code de réponse HTTP 200)
    if response.status_code == 200:
        # Extraire les résultats de la réponse JSON
        result = response.text
        
        # Vérifier si le résultat est une chaîne vide
        if not result:
            return None
        else:
            # Convertir le résultat en dataframe
            df = pd.read_json(result)
            return df
    else:
        print(f'Erreur lors de la requête vers l\'API : erreur {response.status_code}')
        return None

# %%
url_check_id = "http://127.0.0.1:5000/check_id"
url_identite_client = "http://127.0.0.1:5000/client_id"
url_predict_client = "http://127.0.0.1:5000/predict"
url_inf_client = "http://127.0.0.1:5000/inf_client"

id_client = 100245

# %%
df_origin = predict_loan_approval(id_client, url_identite_client)
df_origin.shape
# Out:
# (25345, 112)

# %%
df_origin = predict_loan_approval(id_client, url_check_id)
df_origin
# Out:
#    SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      100245         Cash_loans           F            N               N
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0            112500      364896      20947.5           315000
#
#    ... AGE DAYS_EMPLOYED_ANOM PREVIOUS_APPLICATION_COUNT MOST_CREDIT_TYPE  \
# 0  ...  37              False                         10  Consumer_credit
#
#   PREVIOUS_LOANS_COUNT  CREDIT_PERCENT_INCOME  ANNUITY_CREDIT_PERCENT_INCOME  \
# 0                  NaN                3.24352                         0.1862
#
#    CREDIT_REFUND_TIME  DAYS_EMPLOYED_PERCENT  EXT_SOURCE_1
# 0           17.419549               0.104527      0.637953
#
# [1 rows x 112 columns]

# %%
if df_origin.empty :
    # Vérifier l'existance de l'identifiant client via l'API
    print("Ce client n'est pas répertorié")  # Afficher un message indiquant que le client n'est pas répertorié

else: print("le client existe")
# Out:
# le client existe

# %%
df_origin = predict_loan_approval(id_client, url_check_id)
data_origin = df_origin.set_index('SK_ID_CURR')
check = data_origin[data_origin.index == int(id_client)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df_origin = predict_loan_approval(id_client, url_check_id)
#       2 data_origin = df_origin.set_index('SK_ID_CURR')
#       3 check = data_origin[data_origin.index == int(id_client)]
#
# Cell In[11], line 21, in predict_loan_approval(id_client, url)
#      17 if response.status_code == 200:
#      18     # Extraire les résultats de la réponse JSON
#      19     #result = response.json()
#      20     result = response.text
# ---> 21     df = pd.read_json(result)
#      22     #df = pd.DataFrame(result)
#      23     return df
#
# ...

# %%
df_origin = predict_loan_approval(id_client, url_identite_client)
data_origin = df_origin.set_index('SK_ID_CURR')
identite_client = data_origin[data_origin.index == int(id_client)]
identite_client.shape
# Out:
# (1, 111)

# %%
# Récupérer les informations client via l'API pour la prédiction 
df_clean = predict_loan_approval(id_client,url_predict_client)
data_clean = df_clean.set_index('SK_ID_CURR')
predict_client = data_clean[data_clean.index == int(id_client)]
predict_client.shape
# Out:
# (1, 209)

# %%
 # Récupérer les informations du client sans normalisation via l'API
df_clean_without_standard = predict_loan_approval(id_client,url_inf_client)
data_clean_without_standard = df_clean_without_standard.set_index('SK_ID_CURR')
client_without_standard = data_clean_without_standard[data_clean_without_standard.index == int(id_client)]
client_without_standard.shape
# Out:
# (1, 209)

# %%
api_url = url_predict_client.replace("{id_client}", str(id_client))

# %%
response = requests.get(api_url)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.text

# %%
df = pd.read_json(data)
df.shape
# Out:
# (1, 210)

# %%
id_client = int(id_client)

# %%
a = ZipFile("data/df_test_imputed.zip") # le dataset final avec Standardisation et encodage

b = ZipFile("data/real_data_clean_test.zip")
# extrait tous les ID client uniques du dataframe et les stocke dans la liste

c = ZipFile("data/test_imputed_without_standardisation.zip")

# %%
def classify_client(model, ID, df, seuil):
    ID = int(ID)
    X = df[df.index == ID]
    #X = X.drop(['TARGET'], axis=1) #if df_train_imputes.csv
    probability_default_payment = model.predict_proba(X)[:, 1]
    if probability_default_payment >= seuil:
        prediction = "Prêt NON Accordé"
    else:
        prediction = "Prêt Accordé"
    return probability_default_payment, prediction
